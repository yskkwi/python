# %% [markdown]
# <a href="https://colab.research.google.com/github/yskkwi/adding-up/blob/master/python4_%E5%A4%89%E6%95%B0%E3%81%A8format%E9%96%A2%E6%95%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# str型の関数

a_str = '朝は'
print(a_str)
b_str = '寒い'
print(b_str)

print(a_str + b_str)

print(a_str + '眠い')

print(a_str * 3)
# Out:
# 朝は
# 寒い
# 朝は寒い
# 朝は眠い
# 朝は朝は朝は

# %%
# int型の関数

a=2
print(a)

b=3
print(b)

c=4
print(c)

print(a+b*c)

print(str(a) + ' + ' + str(b) + ' = '+ str(a+b))

print('a' + '+' + 'b' + '=' + 'a+b')
# Out:
# 2
# 3
# 4
# 14
# 2 + 3 = 5
# a+b=a+b

# %%
# format関数　は　次のように使う

print('{0} + {1} = {2}'.format(a,b,a+b))
# Out:
# 2 + 3 = 5

# %%
# 次のようにも使える

print('{ai} + {bii} = {ciii}'.format(ai=a,bii=b,ciii=a+b))
# Out:
# 2 + 3 = 5

# %%
print('Depth:{0} * Width:{1} * Height:{2} = Cubic:{3}'.format(a,b,c,a*b*c))
# Out:
# Depth:2 * Width:3 * Height:4 = Cubic:24

# %%
print("index0 5桁 = {0:05d}, index1 6桁 = {1:06d}".format(43, 876))
# Out:
# index0 5桁 = 00043, index1 6桁 = 000876
