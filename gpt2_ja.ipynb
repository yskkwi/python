# %% [markdown]
# <a href="https://colab.research.google.com/github/yskkwi/python/blob/master/gpt2_ja.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers
# Out:
# ...
#      |████████████████████████████████| 3.5 MB 11.4 MB/s
# ...
#      |████████████████████████████████| 67 kB 3.7 MB/s
# ...
#      |████████████████████████████████| 6.8 MB 40.7 MB/s
# ...
#      |████████████████████████████████| 895 kB 40.8 MB/s
# ...
#      |████████████████████████████████| 596 kB 19.6 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
pip install torch

# %%
pip install sentencepiece
# Out:
# ...
#      |████████████████████████████████| 1.2 MB 12.6 MB/s
# ...

# %%
import transformers

# %%
pipeline = transformers.pipeline("text-generation", "colorfulscoop/gpt2-small-ja")
# Out:
# Downloading:   0%|          | 0.00/940 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/328 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/784k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/129 [00:00<?, ?B/s]

# %%
pipeline("統計的機械学習でのニューラルネットワーク", do_sample=True, top_p=0.95, top_k=50, num_return_sequences=3)
# Out:
# [{'generated_text': '統計的機械学習でのニューラルネットワーク学習の必要性がますます高まっている。このようなニューラルネットワーク学習'},
#  {'generated_text': '統計的機械学習でのニューラルネットワークの概念を導入し、新たなアルゴリズムに機械学習を導入した。ニューラル'},
#  {'generated_text': '統計的機械学習でのニューラルネットワークの役割を強調している。新しい学習アルゴリズムや統計的手法など'}]
